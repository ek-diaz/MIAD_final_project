# %%
import numpy as np
import pandas as pd
import boto3
import sagemaker
import logging

from sagemaker import RandomCutForest
from sagemaker.serializers import CSVSerializer
from sagemaker.deserializers import JSONDeserializer
from dataclasses import dataclass

# Configure logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)


# AWS and model configuration
@dataclass
class AWSConfig:
    bucket: str = 'nequi-data'
    prefix: str = 'sandbox_co/jupadill/sagemaker/rcf/contugas'
    instance_type: str = 'ml.c5.xlarge'
    instance_count: int = 1
    num_samples_per_tree: int = 512
    num_trees: int = 200


class ModelError(Exception):
    pass


# Utility to shingle time-series data
def shingle(data: np.ndarray, shingle_size: int) -> np.ndarray:
    num_samples, num_features = data.shape
    if num_samples <= shingle_size:
        raise ValueError("Data length must be greater than shingle size")
    shingled = np.zeros((num_samples - shingle_size, shingle_size * num_features))
    for i in range(num_samples - shingle_size):
        window = data[i:i + shingle_size]
        shingled[i] = window.flatten()
    return shingled


# RCF model wrapper
class RandomCutForestModel:
    def __init__(self, aws_config: AWSConfig):
        self.config = aws_config
        try:
            self.session = sagemaker.Session()
            self.execution_role = sagemaker.get_execution_role()
        except Exception as e:
            logger.error(f"Failed to init SageMaker session: {e}")
            raise ModelError from e
        self.model = None
        self.endpoint = None

    def initialize_model(self):
        self.model = RandomCutForest(
            role=self.execution_role,
            instance_count=self.config.instance_count,
            instance_type=self.config.instance_type,
            num_samples_per_tree=self.config.num_samples_per_tree,
            num_trees=self.config.num_trees,
            data_location=f"s3://{self.config.bucket}/{self.config.prefix}",
            output_path=f"s3://{self.config.bucket}/{self.config.prefix}/output"
        )

    def train(self, data: np.ndarray):
        if not self.model:
            self.initialize_model()
        logger.info("Training model...")
        self.model.fit(self.model.record_set(data))

    def deploy(self):
        logger.info("Deploying endpoint...")
        self.endpoint = self.model.deploy(
            initial_instance_count=self.config.instance_count,
            instance_type=self.config.instance_type
        )
        self.endpoint.serializer = CSVSerializer()
        self.endpoint.deserializer = JSONDeserializer()

    def predict(self, data: np.ndarray, batch_size: int = 100) -> list:
        if not self.endpoint:
            raise ModelError("Endpoint not deployed")
        scores = []
        for i in range(0, len(data), batch_size):
            batch = data[i:i+batch_size]
            payload = "\n".join(",".join(map(str, row)) for row in batch)
            resp = self.endpoint.predict(payload)
            scores.extend([item['score'] for item in resp['scores']])
        return scores

    def cleanup(self):
        if self.endpoint:
            logger.info("Deleting endpoint...")
            self.endpoint.delete_endpoint()


# Prepare shingled data for any cluster
def prepare_data(df: pd.DataFrame, shingle_size: int, cluster: int) -> tuple[pd.DataFrame, np.ndarray]:
    subset = df[df['Cluster'] == cluster].copy()
    features = subset.iloc[:, 2:5].to_numpy()
    shingled = shingle(features, shingle_size)
    aligned = subset.iloc[shingle_size:].copy()
    return aligned, shingled


# Main processing
def main():
    data = pd.read_csv("./contugas_clean_extra.csv")
    aws_config = AWSConfig()
    results = []

    for cluster_id in sorted(data['Cluster'].unique()):
        logger.info(f"Processing Cluster {cluster_id}")
        aligned_df, shingled_data = prepare_data(data, shingle_size=24, cluster=cluster_id)

        model = RandomCutForestModel(aws_config)
        model.train(shingled_data)
        model.deploy()
        scores = model.predict(shingled_data)
        model.cleanup()

        aligned_df['score'] = scores
        results.append(aligned_df)

    # Combine all clusters
    all_scores_df = pd.concat(results)
    all_scores_df.to_csv("anomaly_scores_all_clusters.csv", index=False)
    logger.info("Exported results to anomaly_scores_all_clusters.csv")


if __name__ == "__main__":
    main()
# Out:
# INFO:__main__:Processing Cluster 0
# INFO:__main__:Training model...
# INFO:sagemaker.image_uris:Same images used for training and inference. Defaulting to image scope: inference.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker.image_uris:Same images used for training and inference. Defaulting to image scope: inference.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker:Creating training-job with name: randomcutforest-2025-05-20-12-00-51-037
# 2025-05-20 12:00:56 Starting - Starting the training job...
# 2025-05-20 12:01:11 Starting - Preparing the instances for training...
# 2025-05-20 12:01:56 Downloading - Downloading the training image.........
# 2025-05-20 12:03:22 Training - Training image download completed. Training in progress..Docker entrypoint called with argument(s): train
# Running default environment configuration script
# /opt/amazon/lib/python3.8/site-packages/mxnet/model.py:97: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if num_device is 1 and 'dist' not in kvstore:
# /opt/amazon/lib/python3.8/site-packages/scipy/optimize/_shgo.py:495: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if cons['type'] is 'ineq':
# /opt/amazon/lib/python3.8/site-packages/scipy/optimize/_shgo.py:743: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if len(self.X_min) is not 0:
# [05/20/2025 12:03:29 INFO 140669341112128] Reading default configuration from /opt/amazon/lib/python3.8/site-packages/algorithm/resources/default-conf.json: {'num_samples_per_tree': 256, 'num_trees': 100, 'force_dense': 'true', 'eval_metrics': ['accuracy', 'precision_recall_fscore'], 'epochs': 1, 'mini_batch_size': 1000, '_log_level': 'info', '_kvstore': 'dist_async', '_num_kv_servers': 'auto', '_num_gpus': 'auto', '_tuning_objective_metric': '', '_ftp_port': 8999}
# [05/20/2025 12:03:29 INFO 140669341112128] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'feature_dim': '72', 'mini_batch_size': '1000', 'num_samples_per_tree': '512', 'num_trees': '200'}
# [05/20/2025 12:03:30 INFO 140669341112128] Final configuration: {'num_samples_per_tree': '512', 'num_trees': '200', 'force_dense': 'true', 'eval_metrics': ['accuracy', 'precision_recall_fscore'], 'epochs': 1, 'mini_batch_size': '1000', '_log_level': 'info', '_kvstore': 'dist_async', '_num_kv_servers': 'auto', '_num_gpus': 'auto', '_tuning_objective_metric': '', '_ftp_port': 8999, 'feature_dim': '72'}
# [05/20/2025 12:03:30 WARNING 140669341112128] Loggers have already been setup.
# [05/20/2025 12:03:30 INFO 140669341112128] Launching parameter server for role scheduler
# [05/20/2025 12:03:30 INFO 140669341112128] {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-0-195-132.ec2.internal', 'TRAINING_JOB_NAME': 'randomcutforest-2025-05-20-12-00-51-037', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:177333342796:training-job/randomcutforest-2025-05-20-12-00-51-037', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/proxy-6088e96aba0a3d7f59216f86bc8189403278fd0833ec0b317fd0c46dbae027e5-customer', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.8/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'SAGEMAKER_MANAGED_WARMPOOL_CACHE_DIRECTORY': '/opt/ml/sagemaker/warmpoolcache', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'CUDA_VERSION': '11.1', 'HOME': '/root', 'SHLVL': '1', 'CUDA_COMPAT_NDRIVER_SUPPORTED_VERSION': '455.32.00', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE'}
# [05/20/2025 12:03:30 INFO 140669341112128] envs={'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-0-195-132.ec2.internal', 'TRAINING_JOB_NAME': 'randomcutforest-2025-05-20-12-00-51-037', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:177333342796:training-job/randomcutforest-2025-05-20-12-00-51-037', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/proxy-6088e96aba0a3d7f59216f86bc8189403278fd0833ec0b317fd0c46dbae027e5-customer', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.8/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'SAGEMAKER_MANAGED_WARMPOOL_CACHE_DIRECTORY': '/opt/ml/sagemaker/warmpoolcache', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'CUDA_VERSION': '11.1', 'HOME': '/root', 'SHLVL': '1', 'CUDA_COMPAT_NDRIVER_SUPPORTED_VERSION': '455.32.00', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE', 'DMLC_ROLE': 'scheduler', 'DMLC_PS_ROOT_URI': '10.0.195.132', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '1', 'DMLC_NUM_WORKER': '1'}
# [05/20/2025 12:03:30 INFO 140669341112128] Launching parameter server for role server
# [05/20/2025 12:03:30 INFO 140669341112128] {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-0-195-132.ec2.internal', 'TRAINING_JOB_NAME': 'randomcutforest-2025-05-20-12-00-51-037', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:177333342796:training-job/randomcutforest-2025-05-20-12-00-51-037', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/proxy-6088e96aba0a3d7f59216f86bc8189403278fd0833ec0b317fd0c46dbae027e5-customer', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.8/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'SAGEMAKER_MANAGED_WARMPOOL_CACHE_DIRECTORY': '/opt/ml/sagemaker/warmpoolcache', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'CUDA_VERSION': '11.1', 'HOME': '/root', 'SHLVL': '1', 'CUDA_COMPAT_NDRIVER_SUPPORTED_VERSION': '455.32.00', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE'}
# [05/20/2025 12:03:30 INFO 140669341112128] envs={'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-0-195-132.ec2.internal', 'TRAINING_JOB_NAME': 'randomcutforest-2025-05-20-12-00-51-037', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:177333342796:training-job/randomcutforest-2025-05-20-12-00-51-037', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/proxy-6088e96aba0a3d7f59216f86bc8189403278fd0833ec0b317fd0c46dbae027e5-customer', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.8/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'SAGEMAKER_MANAGED_WARMPOOL_CACHE_DIRECTORY': '/opt/ml/sagemaker/warmpoolcache', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'CUDA_VERSION': '11.1', 'HOME': '/root', 'SHLVL': '1', 'CUDA_COMPAT_NDRIVER_SUPPORTED_VERSION': '455.32.00', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE', 'DMLC_ROLE': 'server', 'DMLC_PS_ROOT_URI': '10.0.195.132', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '1', 'DMLC_NUM_WORKER': '1'}
# [05/20/2025 12:03:30 INFO 140669341112128] Environment: {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-0-195-132.ec2.internal', 'TRAINING_JOB_NAME': 'randomcutforest-2025-05-20-12-00-51-037', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:177333342796:training-job/randomcutforest-2025-05-20-12-00-51-037', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/proxy-6088e96aba0a3d7f59216f86bc8189403278fd0833ec0b317fd0c46dbae027e5-customer', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.8/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'SAGEMAKER_MANAGED_WARMPOOL_CACHE_DIRECTORY': '/opt/ml/sagemaker/warmpoolcache', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'CUDA_VERSION': '11.1', 'HOME': '/root', 'SHLVL': '1', 'CUDA_COMPAT_NDRIVER_SUPPORTED_VERSION': '455.32.00', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE', 'DMLC_ROLE': 'worker', 'DMLC_PS_ROOT_URI': '10.0.195.132', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '1', 'DMLC_NUM_WORKER': '1'}
# Process 34 is a shell:scheduler.
# Process 43 is a shell:server.
# Process 7 is a worker.
# [05/20/2025 12:03:30 INFO 140669341112128] Using default worker.
# [05/20/2025 12:03:30 INFO 140669341112128] Loaded iterator creator application/x-recordio-protobuf for content type ('application/x-recordio-protobuf', '1.0')
# [05/20/2025 12:03:30 INFO 140669341112128] Checkpoint loading and saving are disabled.
# [05/20/2025 12:03:30 INFO 140669341112128] Verifying hyperparamemters...
# [05/20/2025 12:03:30 INFO 140669341112128] Hyperparameters are correct.
# [05/20/2025 12:03:30 INFO 140669341112128] Validating that feature_dim agrees with dimensions in training data...
# [05/20/2025 12:03:30 INFO 140669341112128] feature_dim is correct.
# [05/20/2025 12:03:30 INFO 140669341112128] Validating memory limits...
# [05/20/2025 12:03:30 INFO 140669341112128] Available memory in bytes: 6558908416
# [05/20/2025 12:03:30 INFO 140669341112128] Estimated sample size in bytes: 117964800
# [05/20/2025 12:03:30 INFO 140669341112128] Estimated memory needed to build the forest in bytes: 294912000
# [05/20/2025 12:03:30 INFO 140669341112128] Memory limits validated.
# [05/20/2025 12:03:30 INFO 140669341112128] Starting cluster sharing facilities...
# [05/20/2025 12:03:30 INFO 140666780759808] concurrency model: async
# [05/20/2025 12:03:30 INFO 140666780759808] masquerade (NAT) address: None
# [05/20/2025 12:03:30 INFO 140669341112128] Create Store: dist_async
# [05/20/2025 12:03:30 INFO 140666780759808] passive ports: None
# [05/20/2025 12:03:30 INFO 140666780759808] >>> starting FTP server on 0.0.0.0:8999, pid=7 <<<
# [05/20/2025 12:03:31 INFO 140669341112128] Cluster sharing facilities started.
# [05/20/2025 12:03:31 INFO 140669341112128] Verifying all workers are accessible...
# [05/20/2025 12:03:31 INFO 140669341112128] All workers accessible.
# [05/20/2025 12:03:31 INFO 140669341112128] Initializing Sampler...
# [05/20/2025 12:03:31 INFO 140669341112128] Sampler correctly initialized.
# #metrics {"StartTime": 1747742610.0248384, "EndTime": 1747742611.0395093, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 1007.3637962341309, "count": 1, "min": 1007.3637962341309, "max": 1007.3637962341309}}}
# #metrics {"StartTime": 1747742611.039658, "EndTime": 1747742611.0396953, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [2025-05-20 12:03:31.042] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 1017, "num_examples": 1, "num_bytes": 604000}
# [05/20/2025 12:03:31 INFO 140669341112128] Sampling training data...
# [2025-05-20 12:03:31.184] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 141, "num_examples": 131, "num_bytes": 78829248}
# [05/20/2025 12:03:31 INFO 140669341112128] Sampling training data completed.
# #metrics {"StartTime": 1747742611.0396116, "EndTime": 1747742611.2951944, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training"}, "Metrics": {"epochs": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "update.time": {"sum": 252.41470336914062, "count": 1, "min": 252.41470336914062, "max": 252.41470336914062}}}
# [05/20/2025 12:03:31 INFO 140669341112128] Early stop condition met. Stopping training.
# [05/20/2025 12:03:31 INFO 140669341112128] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"StartTime": 1747742611.042751, "EndTime": 1747742611.2955468, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 130512.0, "count": 1, "min": 130512, "max": 130512}, "Total Batches Seen": {"sum": 131.0, "count": 1, "min": 131, "max": 131}, "Max Records Seen Between Resets": {"sum": 130512.0, "count": 1, "min": 130512, "max": 130512}, "Max Batches Seen Between Resets": {"sum": 131.0, "count": 1, "min": 131, "max": 131}, "Reset Count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Number of Records Since Last Reset": {"sum": 130512.0, "count": 1, "min": 130512, "max": 130512}, "Number of Batches Since Last Reset": {"sum": 131.0, "count": 1, "min": 131, "max": 131}}}
# [05/20/2025 12:03:31 INFO 140669341112128] #throughput_metric: host=algo-1, train throughput=515903.8508968356 records/second
# [05/20/2025 12:03:31 INFO 140669341112128] Master node: building Random Cut Forest...
# [05/20/2025 12:03:31 INFO 140669341112128] Gathering samples...
# [05/20/2025 12:03:31 INFO 140669341112128] 102400 samples gathered
# [05/20/2025 12:03:31 INFO 140669341112128] Building Random Cut Forest...
# [05/20/2025 12:03:31 INFO 140669341112128] Random Cut Forest built:
# ForestInfo{num_trees: 200, num_samples_in_forest: 102400, num_samples_per_tree: 512, sample_dim: 72, shingle_size: 1, trees_num_nodes: [1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, ], trees_depth: [24, 25, 30, 28, 29, 26, 27, 28, 25, 27, 27, 28, 25, 24, 23, 32, 24, 23, 22, 26, 29, 26, 24, 30, 31, 25, 25, 28, 24, 32, 22, 22, 25, 27, 26, 27, 25, 23, 33, 26, 25, 30, 27, 26, 25, 25, 30, 25, 37, 31, 28, 27, 31, 22, 23, 24, 27, 28, 24, 30, 30, 25, 24, 25, 25, 26, 27, 25, 31, 27, 26, 23, 23, 31, 24, 28, 23, 26, 26, 23, 27, 22, 25, 34, 27, 23, 22, 23, 26, 28, 27, 26, 22, 24, 28, 35, 30, 24, 25, 27, 26, 27, 25, 28, 22, 23, 27, 24, 31, 28, 26, 29, 24, 26, 32, 35, 32, 27, 25, 30, 26, 25, 26, 35, 28, 22, 25, 31, 24, 28, 26, 27, 21, 30, 24, 33, 25, 27, 28, 26, 28, 26, 28, 27, 32, 25, 23, 32, 25, 28, 24, 28, 31, 25, 27, 27, 32, 25, 24, 24, 28, 32, 30, 25, 25, 26, 22, 25, 34, 22, 25, 30, 25, 32, 25, 21, 24, 24, 24, 25, 29, 23, 24, 27, 30, 26, 29, 23, 24, 24, 25, 33, 26, 24, 31, 25, 25, 24, 34, 21, ], max_num_nodes: 1023, min_num_nodes: 1023, avg_num_nodes: 1023, max_tree_depth: 37, min_tree_depth: 21, avg_tree_depth: 26, mem_size: 253705648}
# #metrics {"StartTime": 1747742611.295273, "EndTime": 1747742611.85371, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training"}, "Metrics": {"fit_model.time": {"sum": 438.16161155700684, "count": 1, "min": 438.16161155700684, "max": 438.16161155700684}, "model.bytes": {"sum": 253705648.0, "count": 1, "min": 253705648, "max": 253705648}, "finalize.time": {"sum": 557.8064918518066, "count": 1, "min": 557.8064918518066, "max": 557.8064918518066}}}
# [05/20/2025 12:03:37 INFO 140669341112128] Master node: Serializing the RandomCutForest model
# #metrics {"StartTime": 1747742611.853805, "EndTime": 1747742617.0053425, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training"}, "Metrics": {"serialize_model.time": {"sum": 5151.488780975342, "count": 1, "min": 5151.488780975342, "max": 5151.488780975342}}}
# [05/20/2025 12:03:37 INFO 140669341112128] Test data is not provided.
# #metrics {"StartTime": 1747742617.0054135, "EndTime": 1747742617.048533, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training"}, "Metrics": {"setuptime": {"sum": 22.768259048461914, "count": 1, "min": 22.768259048461914, "max": 22.768259048461914}, "totaltime": {"sum": 7051.305770874023, "count": 1, "min": 7051.305770874023, "max": 7051.305770874023}}}
#
# 2025-05-20 12:03:42 Uploading - Uploading generated training model
# 2025-05-20 12:04:05 Completed - Training job completed
# INFO:__main__:Deploying endpoint...
# INFO:sagemaker.image_uris:Same images used for training and inference. Defaulting to image scope: inference.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker:Creating model with name: randomcutforest-2025-05-20-12-04-38-592
# Training seconds: 155
# Billable seconds: 155
# INFO:sagemaker:Creating endpoint-config with name randomcutforest-2025-05-20-12-04-38-592
# INFO:sagemaker:Creating endpoint with name randomcutforest-2025-05-20-12-04-38-592
# ---------!
# INFO:__main__:Deleting endpoint...
# INFO:sagemaker:Deleting endpoint configuration with name: randomcutforest-2025-05-20-12-04-38-592
# INFO:sagemaker:Deleting endpoint with name: randomcutforest-2025-05-20-12-04-38-592
# INFO:__main__:Processing Cluster 1
# INFO:__main__:Training model...
# INFO:sagemaker.image_uris:Same images used for training and inference. Defaulting to image scope: inference.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker.image_uris:Same images used for training and inference. Defaulting to image scope: inference.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker:Creating training-job with name: randomcutforest-2025-05-20-12-12-01-333
# 2025-05-20 12:12:05 Starting - Starting the training job...
# 2025-05-20 12:12:19 Starting - Preparing the instances for training...
# 2025-05-20 12:12:54 Downloading - Downloading the training image.........
# 2025-05-20 12:14:20 Training - Training image download completed. Training in progress.Docker entrypoint called with argument(s): train
# Running default environment configuration script
# /opt/amazon/lib/python3.8/site-packages/mxnet/model.py:97: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if num_device is 1 and 'dist' not in kvstore:
# /opt/amazon/lib/python3.8/site-packages/scipy/optimize/_shgo.py:495: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if cons['type'] is 'ineq':
# /opt/amazon/lib/python3.8/site-packages/scipy/optimize/_shgo.py:743: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if len(self.X_min) is not 0:
# [05/20/2025 12:14:27 INFO 140268098164544] Reading default configuration from /opt/amazon/lib/python3.8/site-packages/algorithm/resources/default-conf.json: {'num_samples_per_tree': 256, 'num_trees': 100, 'force_dense': 'true', 'eval_metrics': ['accuracy', 'precision_recall_fscore'], 'epochs': 1, 'mini_batch_size': 1000, '_log_level': 'info', '_kvstore': 'dist_async', '_num_kv_servers': 'auto', '_num_gpus': 'auto', '_tuning_objective_metric': '', '_ftp_port': 8999}
# [05/20/2025 12:14:27 INFO 140268098164544] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'feature_dim': '72', 'mini_batch_size': '1000', 'num_samples_per_tree': '512', 'num_trees': '200'}
# [05/20/2025 12:14:27 INFO 140268098164544] Final configuration: {'num_samples_per_tree': '512', 'num_trees': '200', 'force_dense': 'true', 'eval_metrics': ['accuracy', 'precision_recall_fscore'], 'epochs': 1, 'mini_batch_size': '1000', '_log_level': 'info', '_kvstore': 'dist_async', '_num_kv_servers': 'auto', '_num_gpus': 'auto', '_tuning_objective_metric': '', '_ftp_port': 8999, 'feature_dim': '72'}
# [05/20/2025 12:14:27 WARNING 140268098164544] Loggers have already been setup.
# [05/20/2025 12:14:27 INFO 140268098164544] Launching parameter server for role scheduler
# [05/20/2025 12:14:27 INFO 140268098164544] {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-2-197-69.ec2.internal', 'TRAINING_JOB_NAME': 'randomcutforest-2025-05-20-12-12-01-333', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:177333342796:training-job/randomcutforest-2025-05-20-12-12-01-333', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/proxy-3dc9edfebaa6e87fa09cdf1299a05d3c513e8ad4c683855cfbea49bb08053030-customer', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.8/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'SAGEMAKER_MANAGED_WARMPOOL_CACHE_DIRECTORY': '/opt/ml/sagemaker/warmpoolcache', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'CUDA_VERSION': '11.1', 'HOME': '/root', 'SHLVL': '1', 'CUDA_COMPAT_NDRIVER_SUPPORTED_VERSION': '455.32.00', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE'}
# [05/20/2025 12:14:27 INFO 140268098164544] envs={'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-2-197-69.ec2.internal', 'TRAINING_JOB_NAME': 'randomcutforest-2025-05-20-12-12-01-333', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:177333342796:training-job/randomcutforest-2025-05-20-12-12-01-333', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/proxy-3dc9edfebaa6e87fa09cdf1299a05d3c513e8ad4c683855cfbea49bb08053030-customer', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.8/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'SAGEMAKER_MANAGED_WARMPOOL_CACHE_DIRECTORY': '/opt/ml/sagemaker/warmpoolcache', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'CUDA_VERSION': '11.1', 'HOME': '/root', 'SHLVL': '1', 'CUDA_COMPAT_NDRIVER_SUPPORTED_VERSION': '455.32.00', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE', 'DMLC_ROLE': 'scheduler', 'DMLC_PS_ROOT_URI': '10.2.197.69', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '1', 'DMLC_NUM_WORKER': '1'}
# [05/20/2025 12:14:27 INFO 140268098164544] Launching parameter server for role server
# [05/20/2025 12:14:27 INFO 140268098164544] {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-2-197-69.ec2.internal', 'TRAINING_JOB_NAME': 'randomcutforest-2025-05-20-12-12-01-333', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:177333342796:training-job/randomcutforest-2025-05-20-12-12-01-333', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/proxy-3dc9edfebaa6e87fa09cdf1299a05d3c513e8ad4c683855cfbea49bb08053030-customer', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.8/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'SAGEMAKER_MANAGED_WARMPOOL_CACHE_DIRECTORY': '/opt/ml/sagemaker/warmpoolcache', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'CUDA_VERSION': '11.1', 'HOME': '/root', 'SHLVL': '1', 'CUDA_COMPAT_NDRIVER_SUPPORTED_VERSION': '455.32.00', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE'}
# [05/20/2025 12:14:27 INFO 140268098164544] envs={'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-2-197-69.ec2.internal', 'TRAINING_JOB_NAME': 'randomcutforest-2025-05-20-12-12-01-333', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:177333342796:training-job/randomcutforest-2025-05-20-12-12-01-333', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/proxy-3dc9edfebaa6e87fa09cdf1299a05d3c513e8ad4c683855cfbea49bb08053030-customer', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.8/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'SAGEMAKER_MANAGED_WARMPOOL_CACHE_DIRECTORY': '/opt/ml/sagemaker/warmpoolcache', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'CUDA_VERSION': '11.1', 'HOME': '/root', 'SHLVL': '1', 'CUDA_COMPAT_NDRIVER_SUPPORTED_VERSION': '455.32.00', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE', 'DMLC_ROLE': 'server', 'DMLC_PS_ROOT_URI': '10.2.197.69', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '1', 'DMLC_NUM_WORKER': '1'}
# [05/20/2025 12:14:27 INFO 140268098164544] Environment: {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-2-197-69.ec2.internal', 'TRAINING_JOB_NAME': 'randomcutforest-2025-05-20-12-12-01-333', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:177333342796:training-job/randomcutforest-2025-05-20-12-12-01-333', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/proxy-3dc9edfebaa6e87fa09cdf1299a05d3c513e8ad4c683855cfbea49bb08053030-customer', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.8/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'SAGEMAKER_MANAGED_WARMPOOL_CACHE_DIRECTORY': '/opt/ml/sagemaker/warmpoolcache', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'CUDA_VERSION': '11.1', 'HOME': '/root', 'SHLVL': '1', 'CUDA_COMPAT_NDRIVER_SUPPORTED_VERSION': '455.32.00', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE', 'DMLC_ROLE': 'worker', 'DMLC_PS_ROOT_URI': '10.2.197.69', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '1', 'DMLC_NUM_WORKER': '1'}
# Process 34 is a shell:scheduler.
# Process 43 is a shell:server.
# Process 7 is a worker.
# [05/20/2025 12:14:27 INFO 140268098164544] Using default worker.
# [05/20/2025 12:14:27 INFO 140268098164544] Loaded iterator creator application/x-recordio-protobuf for content type ('application/x-recordio-protobuf', '1.0')
# [05/20/2025 12:14:27 INFO 140268098164544] Checkpoint loading and saving are disabled.
# [05/20/2025 12:14:27 INFO 140268098164544] Verifying hyperparamemters...
# [05/20/2025 12:14:27 INFO 140268098164544] Hyperparameters are correct.
# [05/20/2025 12:14:27 INFO 140268098164544] Validating that feature_dim agrees with dimensions in training data...
# [05/20/2025 12:14:27 INFO 140268098164544] feature_dim is correct.
# [05/20/2025 12:14:27 INFO 140268098164544] Validating memory limits...
# [05/20/2025 12:14:27 INFO 140268098164544] Available memory in bytes: 6614904832
# [05/20/2025 12:14:27 INFO 140268098164544] Estimated sample size in bytes: 117964800
# [05/20/2025 12:14:27 INFO 140268098164544] Estimated memory needed to build the forest in bytes: 294912000
# [05/20/2025 12:14:27 INFO 140268098164544] Memory limits validated.
# [05/20/2025 12:14:27 INFO 140268098164544] Starting cluster sharing facilities...
# [05/20/2025 12:14:27 INFO 140265536861952] concurrency model: async
# [05/20/2025 12:14:27 INFO 140268098164544] Create Store: dist_async
# [05/20/2025 12:14:27 INFO 140265536861952] masquerade (NAT) address: None
# [05/20/2025 12:14:27 INFO 140265536861952] passive ports: None
# [05/20/2025 12:14:27 INFO 140265536861952] >>> starting FTP server on 0.0.0.0:8999, pid=7 <<<
# [05/20/2025 12:14:28 INFO 140268098164544] Cluster sharing facilities started.
# [05/20/2025 12:14:28 INFO 140268098164544] Verifying all workers are accessible...
# [05/20/2025 12:14:28 INFO 140268098164544] All workers accessible.
# [05/20/2025 12:14:28 INFO 140268098164544] Initializing Sampler...
# [05/20/2025 12:14:28 INFO 140268098164544] Sampler correctly initialized.
# #metrics {"StartTime": 1747743267.5618632, "EndTime": 1747743268.5458667, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 977.358341217041, "count": 1, "min": 977.358341217041, "max": 977.358341217041}}}
# #metrics {"StartTime": 1747743268.546005, "EndTime": 1747743268.5460403, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [2025-05-20 12:14:28.548] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 986, "num_examples": 1, "num_bytes": 604000}
# [05/20/2025 12:14:28 INFO 140268098164544] Sampling training data...
# [2025-05-20 12:14:28.683] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 134, "num_examples": 131, "num_bytes": 78829248}
# [05/20/2025 12:14:28 INFO 140268098164544] Sampling training data completed.
# #metrics {"StartTime": 1747743268.5459602, "EndTime": 1747743268.7824259, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training"}, "Metrics": {"epochs": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "update.time": {"sum": 233.45327377319336, "count": 1, "min": 233.45327377319336, "max": 233.45327377319336}}}
# [05/20/2025 12:14:28 INFO 140268098164544] Early stop condition met. Stopping training.
# [05/20/2025 12:14:28 INFO 140268098164544] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"StartTime": 1747743268.5489464, "EndTime": 1747743268.7827134, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 130512.0, "count": 1, "min": 130512, "max": 130512}, "Total Batches Seen": {"sum": 131.0, "count": 1, "min": 131, "max": 131}, "Max Records Seen Between Resets": {"sum": 130512.0, "count": 1, "min": 130512, "max": 130512}, "Max Batches Seen Between Resets": {"sum": 131.0, "count": 1, "min": 131, "max": 131}, "Reset Count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Number of Records Since Last Reset": {"sum": 130512.0, "count": 1, "min": 130512, "max": 130512}, "Number of Batches Since Last Reset": {"sum": 131.0, "count": 1, "min": 131, "max": 131}}}
# [05/20/2025 12:14:28 INFO 140268098164544] #throughput_metric: host=algo-1, train throughput=558044.4468947069 records/second
# [05/20/2025 12:14:28 INFO 140268098164544] Master node: building Random Cut Forest...
# [05/20/2025 12:14:28 INFO 140268098164544] Gathering samples...
# [05/20/2025 12:14:28 INFO 140268098164544] 102400 samples gathered
# [05/20/2025 12:14:28 INFO 140268098164544] Building Random Cut Forest...
# [05/20/2025 12:14:29 INFO 140268098164544] Random Cut Forest built:
# ForestInfo{num_trees: 200, num_samples_in_forest: 102400, num_samples_per_tree: 512, sample_dim: 72, shingle_size: 1, trees_num_nodes: [1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, 1023, ], trees_depth: [35, 41, 30, 41, 30, 30, 37, 30, 31, 33, 25, 29, 36, 34, 32, 30, 33, 25, 33, 26, 34, 28, 32, 27, 30, 37, 28, 30, 31, 37, 31, 32, 28, 34, 27, 34, 34, 32, 31, 26, 37, 38, 34, 33, 34, 37, 33, 41, 38, 36, 30, 31, 34, 34, 33, 34, 22, 27, 31, 26, 34, 30, 36, 42, 34, 31, 31, 24, 29, 32, 30, 37, 35, 27, 39, 30, 32, 31, 41, 34, 25, 46, 29, 29, 28, 31, 29, 26, 38, 28, 27, 23, 27, 28, 35, 32, 32, 29, 28, 25, 26, 29, 30, 34, 28, 28, 31, 34, 35, 36, 31, 36, 26, 33, 35, 25, 35, 27, 40, 34, 36, 30, 33, 29, 28, 39, 35, 32, 35, 36, 29, 37, 27, 32, 30, 40, 32, 27, 30, 29, 33, 31, 30, 32, 34, 25, 26, 31, 41, 27, 28, 31, 32, 29, 28, 32, 38, 27, 31, 27, 30, 26, 38, 33, 32, 27, 33, 30, 29, 36, 37, 36, 30, 28, 27, 32, 40, 32, 31, 32, 35, 32, 31, 24, 40, 29, 28, 46, 39, 33, 33, 31, 35, 28, 28, 33, 32, 34, 25, 34, ], max_num_nodes: 1023, min_num_nodes: 1023, avg_num_nodes: 1023, max_tree_depth: 46, min_tree_depth: 22, avg_tree_depth: 31, mem_size: 253705648}
# #metrics {"StartTime": 1747743268.7825048, "EndTime": 1747743269.2985852, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training"}, "Metrics": {"fit_model.time": {"sum": 418.02000999450684, "count": 1, "min": 418.02000999450684, "max": 418.02000999450684}, "model.bytes": {"sum": 253705648.0, "count": 1, "min": 253705648, "max": 253705648}, "finalize.time": {"sum": 515.6054496765137, "count": 1, "min": 515.6054496765137, "max": 515.6054496765137}}}
# [05/20/2025 12:14:34 INFO 140268098164544] Master node: Serializing the RandomCutForest model
# #metrics {"StartTime": 1747743269.298672, "EndTime": 1747743274.1308177, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training"}, "Metrics": {"serialize_model.time": {"sum": 4832.100868225098, "count": 1, "min": 4832.100868225098, "max": 4832.100868225098}}}
# [05/20/2025 12:14:34 INFO 140268098164544] Test data is not provided.
# #metrics {"StartTime": 1747743274.130889, "EndTime": 1747743274.1711316, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training"}, "Metrics": {"setuptime": {"sum": 49.06177520751953, "count": 1, "min": 49.06177520751953, "max": 49.06177520751953}, "totaltime": {"sum": 6663.403749465942, "count": 1, "min": 6663.403749465942, "max": 6663.403749465942}}}
#
# 2025-05-20 12:14:58 Uploading - Uploading generated training model
# 2025-05-20 12:14:58 Completed - Training job completed
# INFO:__main__:Deploying endpoint...
# INFO:sagemaker.image_uris:Same images used for training and inference. Defaulting to image scope: inference.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker:Creating model with name: randomcutforest-2025-05-20-12-15-18-288
# Training seconds: 140
# Billable seconds: 140
# INFO:sagemaker:Creating endpoint-config with name randomcutforest-2025-05-20-12-15-18-288
# INFO:sagemaker:Creating endpoint with name randomcutforest-2025-05-20-12-15-18-288
# ---------!
# INFO:__main__:Deleting endpoint...
# INFO:sagemaker:Deleting endpoint configuration with name: randomcutforest-2025-05-20-12-15-18-288
# INFO:sagemaker:Deleting endpoint with name: randomcutforest-2025-05-20-12-15-18-288
# INFO:__main__:Processing Cluster 2
# INFO:__main__:Training model...
# INFO:sagemaker.image_uris:Same images used for training and inference. Defaulting to image scope: inference.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker.image_uris:Same images used for training and inference. Defaulting to image scope: inference.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker:Creating training-job with name: randomcutforest-2025-05-20-12-23-34-373
# 2025-05-20 12:23:36 Starting - Starting the training job...
# 2025-05-20 12:23:51 Starting - Preparing the instances for training...
# 2025-05-20 12:24:32 Downloading - Downloading the training image............
# 2025-05-20 12:26:34 Training - Training image download completed. Training in progress..Docker entrypoint called with argument(s): train
# Running default environment configuration script
# /opt/amazon/lib/python3.8/site-packages/mxnet/model.py:97: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if num_device is 1 and 'dist' not in kvstore:
# /opt/amazon/lib/python3.8/site-packages/scipy/optimize/_shgo.py:495: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if cons['type'] is 'ineq':
# /opt/amazon/lib/python3.8/site-packages/scipy/optimize/_shgo.py:743: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if len(self.X_min) is not 0:
# [05/20/2025 12:26:40 INFO 139661893678912] Reading default configuration from /opt/amazon/lib/python3.8/site-packages/algorithm/resources/default-conf.json: {'num_samples_per_tree': 256, 'num_trees': 100, 'force_dense': 'true', 'eval_metrics': ['accuracy', 'precision_recall_fscore'], 'epochs': 1, 'mini_batch_size': 1000, '_log_level': 'info', '_kvstore': 'dist_async', '_num_kv_servers': 'auto', '_num_gpus': 'auto', '_tuning_objective_metric': '', '_ftp_port': 8999}
# [05/20/2025 12:26:40 INFO 139661893678912] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'feature_dim': '72', 'mini_batch_size': '1000', 'num_samples_per_tree': '512', 'num_trees': '200'}
# [05/20/2025 12:26:40 INFO 139661893678912] Final configuration: {'num_samples_per_tree': '512', 'num_trees': '200', 'force_dense': 'true', 'eval_metrics': ['accuracy', 'precision_recall_fscore'], 'epochs': 1, 'mini_batch_size': '1000', '_log_level': 'info', '_kvstore': 'dist_async', '_num_kv_servers': 'auto', '_num_gpus': 'auto', '_tuning_objective_metric': '', '_ftp_port': 8999, 'feature_dim': '72'}
# [05/20/2025 12:26:40 WARNING 139661893678912] Loggers have already been setup.
# [05/20/2025 12:26:40 INFO 139661893678912] Launching parameter server for role scheduler
# [05/20/2025 12:26:40 INFO 139661893678912] {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-2-112-127.ec2.internal', 'TRAINING_JOB_NAME': 'randomcutforest-2025-05-20-12-23-34-373', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:177333342796:training-job/randomcutforest-2025-05-20-12-23-34-373', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/proxy-fdc86509964b1ee8396dcb5f2c50f2de4e1c8308becdca145bf6ba37689d7e8a-customer', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.8/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'SAGEMAKER_MANAGED_WARMPOOL_CACHE_DIRECTORY': '/opt/ml/sagemaker/warmpoolcache', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'CUDA_VERSION': '11.1', 'HOME': '/root', 'SHLVL': '1', 'CUDA_COMPAT_NDRIVER_SUPPORTED_VERSION': '455.32.00', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE'}
# [05/20/2025 12:26:40 INFO 139661893678912] envs={'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-2-112-127.ec2.internal', 'TRAINING_JOB_NAME': 'randomcutforest-2025-05-20-12-23-34-373', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:177333342796:training-job/randomcutforest-2025-05-20-12-23-34-373', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/proxy-fdc86509964b1ee8396dcb5f2c50f2de4e1c8308becdca145bf6ba37689d7e8a-customer', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.8/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'SAGEMAKER_MANAGED_WARMPOOL_CACHE_DIRECTORY': '/opt/ml/sagemaker/warmpoolcache', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'CUDA_VERSION': '11.1', 'HOME': '/root', 'SHLVL': '1', 'CUDA_COMPAT_NDRIVER_SUPPORTED_VERSION': '455.32.00', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE', 'DMLC_ROLE': 'scheduler', 'DMLC_PS_ROOT_URI': '10.2.112.127', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '1', 'DMLC_NUM_WORKER': '1'}
# [05/20/2025 12:26:40 INFO 139661893678912] Launching parameter server for role server
# ...
# [05/20/2025 13:12:39 INFO 140043815479104] Launching parameter server for role server
# [05/20/2025 13:12:39 INFO 140043815479104] {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-0-213-219.ec2.internal', 'TRAINING_JOB_NAME': 'randomcutforest-2025-05-20-13-10-09-202', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:177333342796:training-job/randomcutforest-2025-05-20-13-10-09-202', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/proxy-0ba7ecda7146ac2b2c128c2d2e160f8f7839b13d79d6afee65e05441389309c2-customer', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.8/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'SAGEMAKER_MANAGED_WARMPOOL_CACHE_DIRECTORY': '/opt/ml/sagemaker/warmpoolcache', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'CUDA_VERSION': '11.1', 'HOME': '/root', 'SHLVL': '1', 'CUDA_COMPAT_NDRIVER_SUPPORTED_VERSION': '455.32.00', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE'}
# [05/20/2025 13:12:39 INFO 140043815479104] envs={'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-0-213-219.ec2.internal', 'TRAINING_JOB_NAME': 'randomcutforest-2025-05-20-13-10-09-202', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:177333342796:training-job/randomcutforest-2025-05-20-13-10-09-202', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/proxy-0ba7ecda7146ac2b2c128c2d2e160f8f7839b13d79d6afee65e05441389309c2-customer', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.8/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'SAGEMAKER_MANAGED_WARMPOOL_CACHE_DIRECTORY': '/opt/ml/sagemaker/warmpoolcache', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'CUDA_VERSION': '11.1', 'HOME': '/root', 'SHLVL': '1', 'CUDA_COMPAT_NDRIVER_SUPPORTED_VERSION': '455.32.00', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE', 'DMLC_ROLE': 'server', 'DMLC_PS_ROOT_URI': '10.0.213.219', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '1', 'DMLC_NUM_WORKER': '1'}
# [05/20/2025 13:12:39 INFO 140043815479104] Environment: {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-0-213-219.ec2.internal', 'TRAINING_JOB_NAME': 'randomcutforest-2025-05-20-13-10-09-202', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:177333342796:training-job/randomcutforest-2025-05-20-13-10-09-202', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/proxy-0ba7ecda7146ac2b2c128c2d2e160f8f7839b13d79d6afee65e05441389309c2-customer', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.8/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'SAGEMAKER_MANAGED_WARMPOOL_CACHE_DIRECTORY': '/opt/ml/sagemaker/warmpoolcache', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'CUDA_VERSION': '11.1', 'HOME': '/root', 'SHLVL': '1', 'CUDA_COMPAT_NDRIVER_SUPPORTED_VERSION': '455.32.00', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE', 'DMLC_ROLE': 'worker', 'DMLC_PS_ROOT_URI': '10.0.213.219', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '1', 'DMLC_NUM_WORKER': '1'}
# Process 34 is a shell:scheduler.
# Process 43 is a shell:server.
# Process 7 is a worker.
# [05/20/2025 13:12:39 INFO 140043815479104] Using default worker.
# [05/20/2025 13:12:39 INFO 140043815479104] Loaded iterator creator application/x-recordio-protobuf for content type ('application/x-recordio-protobuf', '1.0')
# [05/20/2025 13:12:39 INFO 140043815479104] Checkpoint loading and saving are disabled.
# [05/20/2025 13:12:39 INFO 140043815479104] Verifying hyperparamemters...
# [05/20/2025 13:12:39 INFO 140043815479104] Hyperparameters are correct.
# [05/20/2025 13:12:39 INFO 140043815479104] Validating that feature_dim agrees with dimensions in training data...
# [05/20/2025 13:12:39 INFO 140043815479104] feature_dim is correct.
# [05/20/2025 13:12:39 INFO 140043815479104] Validating memory limits...
# [05/20/2025 13:12:39 INFO 140043815479104] Available memory in bytes: 6560702464
# [05/20/2025 13:12:39 INFO 140043815479104] Estimated sample size in bytes: 117964800
# [05/20/2025 13:12:39 INFO 140043815479104] Estimated memory needed to build the forest in bytes: 294912000
# [05/20/2025 13:12:39 INFO 140043815479104] Memory limits validated.
# [05/20/2025 13:12:39 INFO 140043815479104] Starting cluster sharing facilities...
# [05/20/2025 13:12:39 INFO 140041259038464] concurrency model: async
# [05/20/2025 13:12:39 INFO 140041259038464] masquerade (NAT) address: None
# [05/20/2025 13:12:39 INFO 140043815479104] Create Store: dist_async
# [05/20/2025 13:12:39 INFO 140041259038464] passive ports: None
# [05/20/2025 13:12:39 INFO 140041259038464] >>> starting FTP server on 0.0.0.0:8999, pid=7 <<<
# [05/20/2025 13:12:40 INFO 140043815479104] Cluster sharing facilities started.
# [05/20/2025 13:12:40 INFO 140043815479104] Verifying all workers are accessible...
# [05/20/2025 13:12:40 INFO 140043815479104] All workers accessible.
# [05/20/2025 13:12:40 INFO 140043815479104] Initializing Sampler...
# [05/20/2025 13:12:40 INFO 140043815479104] Sampler correctly initialized.
# #metrics {"StartTime": 1747746759.9353342, "EndTime": 1747746760.8873763, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 944.0817832946777, "count": 1, "min": 944.0817832946777, "max": 944.0817832946777}}}
# #metrics {"StartTime": 1747746760.8875132, "EndTime": 1747746760.8875458, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [2025-05-20 13:12:40.889] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 953, "num_examples": 1, "num_bytes": 604000}
# [05/20/2025 13:12:40 INFO 140043815479104] Sampling training data...
# [2025-05-20 13:12:40.987] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 97, "num_examples": 87, "num_bytes": 52548000}
# [05/20/2025 13:12:41 INFO 140043815479104] Sampling training data completed.
# #metrics {"StartTime": 1747746760.8874714, "EndTime": 1747746761.032563, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training"}, "Metrics": {"epochs": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "update.time": {"sum": 142.90094375610352, "count": 1, "min": 142.90094375610352, "max": 142.90094375610352}}}
# [05/20/2025 13:12:41 INFO 140043815479104] Early stop condition met. Stopping training.
# [05/20/2025 13:12:41 INFO 140043815479104] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"StartTime": 1747746760.8896334, "EndTime": 1747746761.0329394, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 87000.0, "count": 1, "min": 87000, "max": 87000}, "Total Batches Seen": {"sum": 87.0, "count": 1, "min": 87, "max": 87}, "Max Records Seen Between Resets": {"sum": 87000.0, "count": 1, "min": 87000, "max": 87000}, "Max Batches Seen Between Resets": {"sum": 87.0, "count": 1, "min": 87, "max": 87}, "Reset Count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Number of Records Since Last Reset": {"sum": 87000.0, "count": 1, "min": 87000, "max": 87000}, "Number of Batches Since Last Reset": {"sum": 87.0, "count": 1, "min": 87, "max": 87}}}
# [05/20/2025 13:12:41 INFO 140043815479104] #throughput_metric: host=algo-1, train throughput=606519.2931950662 records/second
# [05/20/2025 13:12:41 INFO 140043815479104] Master node: building Random Cut Forest...
# [05/20/2025 13:12:41 INFO 140043815479104] Gathering samples...
# [05/20/2025 13:12:41 INFO 140043815479104] 87000 samples gathered
# [05/20/2025 13:12:41 INFO 140043815479104] Building Random Cut Forest...
# [05/20/2025 13:12:41 INFO 140043815479104] Random Cut Forest built:
# ForestInfo{num_trees: 200, num_samples_in_forest: 87000, num_samples_per_tree: 435, sample_dim: 72, shingle_size: 1, trees_num_nodes: [869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, 869, ], trees_depth: [27, 29, 28, 34, 37, 27, 38, 33, 31, 39, 30, 38, 33, 32, 29, 34, 28, 31, 37, 29, 26, 34, 28, 26, 28, 34, 31, 30, 35, 36, 29, 38, 26, 36, 36, 23, 34, 24, 37, 34, 28, 32, 33, 33, 31, 29, 24, 27, 27, 30, 35, 39, 27, 43, 29, 29, 33, 32, 33, 31, 36, 33, 29, 26, 27, 32, 26, 30, 24, 26, 29, 45, 28, 31, 28, 24, 35, 33, 39, 31, 33, 32, 25, 32, 30, 32, 26, 27, 40, 28, 36, 31, 24, 24, 30, 28, 25, 32, 39, 27, 24, 26, 20, 26, 25, 25, 27, 53, 26, 30, 30, 36, 28, 28, 27, 33, 27, 25, 27, 23, 34, 27, 25, 33, 30, 29, 24, 35, 25, 25, 23, 30, 32, 27, 27, 29, 27, 30, 27, 25, 33, 26, 30, 29, 37, 24, 31, 29, 25, 30, 34, 32, 31, 37, 32, 24, 24, 32, 30, 23, 27, 29, 50, 34, 26, 31, 28, 28, 27, 34, 31, 37, 27, 33, 31, 29, 27, 26, 30, 28, 31, 31, 25, 30, 30, 25, 34, 31, 29, 25, 42, 31, 27, 31, 28, 29, 27, 27, 27, 41, ], max_num_nodes: 869, min_num_nodes: 869, avg_num_nodes: 869, max_tree_depth: 53, min_tree_depth: 20, avg_tree_depth: 30, mem_size: 215513648}
# #metrics {"StartTime": 1747746761.0326765, "EndTime": 1747746761.4859192, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training"}, "Metrics": {"fit_model.time": {"sum": 352.97083854675293, "count": 1, "min": 352.97083854675293, "max": 352.97083854675293}, "model.bytes": {"sum": 215513648.0, "count": 1, "min": 215513648, "max": 215513648}, "finalize.time": {"sum": 452.664852142334, "count": 1, "min": 452.664852142334, "max": 452.664852142334}}}
# [05/20/2025 13:12:45 INFO 140043815479104] Master node: Serializing the RandomCutForest model
# #metrics {"StartTime": 1747746761.4860165, "EndTime": 1747746765.8105452, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training"}, "Metrics": {"serialize_model.time": {"sum": 4324.474811553955, "count": 1, "min": 4324.474811553955, "max": 4324.474811553955}}}
# [05/20/2025 13:12:45 INFO 140043815479104] Test data is not provided.
# #metrics {"StartTime": 1747746765.8106232, "EndTime": 1747746765.8478057, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training"}, "Metrics": {"setuptime": {"sum": 64.68605995178223, "count": 1, "min": 64.68605995178223, "max": 64.68605995178223}, "totaltime": {"sum": 5982.142925262451, "count": 1, "min": 5982.142925262451, "max": 5982.142925262451}}}
#
# 2025-05-20 13:13:06 Uploading - Uploading generated training model
# 2025-05-20 13:13:06 Completed - Training job completed
# INFO:__main__:Deploying endpoint...
# INFO:sagemaker.image_uris:Same images used for training and inference. Defaulting to image scope: inference.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker:Creating model with name: randomcutforest-2025-05-20-13-13-26-713
# Training seconds: 131
# Billable seconds: 131
# INFO:sagemaker:Creating endpoint-config with name randomcutforest-2025-05-20-13-13-26-713
# INFO:sagemaker:Creating endpoint with name randomcutforest-2025-05-20-13-13-26-713
# ----------!
# INFO:__main__:Deleting endpoint...
# INFO:sagemaker:Deleting endpoint configuration with name: randomcutforest-2025-05-20-13-13-26-713
# INFO:sagemaker:Deleting endpoint with name: randomcutforest-2025-05-20-13-13-26-713
# INFO:__main__:Exported results to anomaly_scores_all_clusters.csv

# %%
prueba = pd.read_csv('anomaly_scores_with_levels.csv')

# %%
prueba
# Out:
#         cliente                fecha   presion  temperatura   volumen  \
# 0             6  2019-01-15 00:00:00  0.518345    -0.028506 -1.334240
# 1             6  2019-01-15 01:00:00  0.645290     0.084221 -1.791673
# 2             6  2019-01-15 02:00:00  0.704079    -0.718527 -1.791673
# 3             6  2019-01-15 03:00:00  0.650755    -0.782854 -1.791673
# 4             6  2019-01-15 04:00:00  0.539415     0.069907 -1.286390
# ...         ...                  ...       ...          ...       ...
# 870067       12  2023-12-31 19:00:00 -1.095151     0.569951  0.813947
# 870068       12  2023-12-31 20:00:00 -1.216134     1.424159  0.934506
# 870069       12  2023-12-31 21:00:00 -1.326603     0.522323  0.675552
# 870070       12  2023-12-31 22:00:00 -1.922934     0.601643  0.795676
# 870071       12  2023-12-31 23:00:00 -2.285524     0.879257  0.916962
#
#         Cluster  outlier_multivar     score   level
# 0             0             False  0.740588  Normal
# 1             0             False  0.749864  Normal
# 2             0             False  0.746900  Normal
# 3             0             False  0.767017  Normal
# 4             0             False  0.767443  Normal
# ...         ...               ...       ...     ...
# 870067        6             False  3.523397  Medium
# 870068        6             False  3.492198     Low
# 870069        6             False  3.497812  Medium
# 870070        6             False  3.487027     Low
# 870071        6             False  3.441636     Low
#
# [870072 rows x 9 columns]

# %%
import pandas as pd
import numpy as np

# 1) read your previously exported file
df = pd.read_csv("anomaly_scores_all_clusters.csv")

# 2) same transform logic
means = df.groupby('Cluster')['score'].transform('mean')
stds  = df.groupby('Cluster')['score'].transform('std')

conds = [
    df['score'] <=            means + stds,
    df['score'].between(means + stds, means + 2*stds, inclusive='right'),
    df['score'].between(means + 2*stds, means + 3*stds, inclusive='right'),
    df['score'] >            means + 3*stds
]
labels = ['Normal','Low','Medium','High']
df['level'] = np.select(conds, labels, default='Normal')

# 3) write out your new file
df.to_csv("anomaly_scores_with_levels.csv", index=False)
